# %%
import os
import pandas as pd
import numpy as np

# %%
state = "Iowa"
st = "IA"

# %%
headers = "date,adm1_name,cum_confirmed_cases,population,pos_cases_quarantine,travel_ban_intl_out,travel_ban_intl_in,travel_ban_local,social_distance,work_from_home,no_gathering,school_closure,religious_closure,home_isolation,transit_suspension,pos_cases_quarantine_popwt,travel_ban_local_popwt,social_distance_popwt,work_from_home_popwt,no_gathering_popwt,school_closure_popwt,religious_closure_popwt,business_closure_popwt,federal_guidelines_popwt,home_isolation_popwt,transit_suspension_popwt,mask_intent,social_distance_intent,stay_home_intent,mask_mandate,retail_and_recreation_percent_change_from_baseline,grocery_and_pharmacy_percent_change_from_baseline,parks_percent_change_from_baseline,transit_stations_percent_change_from_baseline,workplaces_percent_change_from_baseline,residential_percent_change_from_baseline"
headers = headers.split(",")
print(headers)
# Out:
# ['date', 'adm1_name', 'cum_confirmed_cases', 'population', 'pos_cases_quarantine', 'travel_ban_intl_out', 'travel_ban_intl_in', 'travel_ban_local', 'social_distance', 'work_from_home', 'no_gathering', 'school_closure', 'religious_closure', 'home_isolation', 'transit_suspension', 'pos_cases_quarantine_popwt', 'travel_ban_local_popwt', 'social_distance_popwt', 'work_from_home_popwt', 'no_gathering_popwt', 'school_closure_popwt', 'religious_closure_popwt', 'business_closure_popwt', 'federal_guidelines_popwt', 'home_isolation_popwt', 'transit_suspension_popwt', 'mask_intent', 'social_distance_intent', 'stay_home_intent', 'mask_mandate', 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'parks_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']

# %%
ill = pd.read_csv("datasets\StatesData\Illinois.csv")
ill[["date", "mask_mandate"]]
# Out:
#           date  mask_mandate
# 0   2020-02-15             0
# 1   2020-02-16             0
# 2   2020-02-17             0
# 3   2020-02-18             0
# 4   2020-02-19             0
# ..         ...           ...
# 82  2020-05-07             1
# 83  2020-05-08             1
# 84  2020-05-09             1
# 85  2020-05-10             1
# 86  2020-05-11             1
#
# [87 rows x 2 columns]

# %%
print("', '".join("date,adm1_name,cum_confirmed_cases,population,pos_cases_quarantine,travel_ban_intl_out,travel_ban_intl_in,travel_ban_local,social_distance,work_from_home,no_gathering,school_closure,religious_closure,home_isolation,transit_suspension,pos_cases_quarantine_popwt,travel_ban_local_popwt,social_distance_popwt,work_from_home_popwt,no_gathering_popwt,school_closure_popwt,religious_closure_popwt,business_closure_popwt,federal_guidelines_popwt,home_isolation_popwt,transit_suspension_popwt".split(",")))
# Out:
# date', 'adm1_name', 'cum_confirmed_cases', 'population', 'pos_cases_quarantine', 'travel_ban_intl_out', 'travel_ban_intl_in', 'travel_ban_local', 'social_distance', 'work_from_home', 'no_gathering', 'school_closure', 'religious_closure', 'home_isolation', 'transit_suspension', 'pos_cases_quarantine_popwt', 'travel_ban_local_popwt', 'social_distance_popwt', 'work_from_home_popwt', 'no_gathering_popwt', 'school_closure_popwt', 'religious_closure_popwt', 'business_closure_popwt', 'federal_guidelines_popwt', 'home_isolation_popwt', 'transit_suspension_popwt

# %%
df1 = pd.read_csv(r"datasets\USA_processed.csv")
print(df1.columns)
df1
# Out:
# Index(['date', 'adm0_name', 'adm1_name', 'cum_confirmed_cases',
#        'cum_confirmed_cases_imputed', 'cum_deaths', 'cum_deaths_imputed',
#        'population', 'lat', 'lon', 'pos_cases_quarantine',
#        'travel_ban_intl_out', 'travel_ban_intl_in', 'travel_ban_local',
#        'social_distance', 'work_from_home', 'no_gathering', 'school_closure',
#        'religious_closure', 'paid_sick_leave', 'business_closure',
#        'federal_guidelines', 'home_isolation', 'transit_suspension',
#        'pos_cases_quarantine_popwt', 'travel_ban_local_popwt',
#        'social_distance_popwt', 'work_from_home_popwt', 'no_gathering_popwt',
#        'school_closure_popwt', 'religious_closure_popwt',
#        'paid_sick_leave_popwt', 'business_closure_popwt',
#        'federal_guidelines_popwt', 'home_isolation_popwt',
#        'transit_suspension_popwt', 'policies_enacted', 'testing_regime'],
#       dtype='object')
#             date adm0_name      adm1_name  cum_confirmed_cases  \
# 0     2020-01-22       USA         Alaska                  0.0
# 1     2020-01-22       USA    Mississippi                  0.0
# 2     2020-01-22       USA       Maryland                  0.0
# 3     2020-01-22       USA      Tennessee                  0.0
# 4     2020-01-22       USA  New Hampshire                  0.0
# ...          ...       ...            ...                  ...
# 5656  2020-05-11       USA        Vermont                926.0
# 5657  2020-05-11       USA         Alaska                382.0
# 5658  2020-05-11       USA  West Virginia               1368.0
# 5659  2020-05-11       USA       Michigan              47544.0
# 5660  2020-05-11       USA        Wyoming                510.0
#
#       cum_confirmed_cases_imputed  cum_deaths  cum_deaths_imputed  population  \
# 0                               0           0                   0    734002.0
# 1                               0           0                   0   2989260.0
# 2                               0           0                   0   6083116.0
# 3                               0           0                   0   6897576.0
# 4                               0           0                   0   1371246.0
# ...                           ...         ...                 ...         ...
# 5656                          926          53                  53    628061.0
# 5657                          382          10                  10    734002.0
# 5658                         1368          57                  57   1778070.0
# 5659                        47544        4585                4585  10045029.0
# 5660                          510           7                   7    567025.0
#
#          lat      lon  ...  no_gathering_popwt  school_closure_popwt  \
# 0     64.228 -152.213  ...            0.000000                   0.0
# 1     32.752  -89.665  ...            0.000000                   0.0
# 2     39.054  -76.799  ...            0.000000                   0.0
# 3     35.844  -86.342  ...            0.000000                   0.0
# 4     43.688  -71.578  ...            0.000000                   0.0
# ...      ...      ...  ...                 ...                   ...
# 5656  44.074  -72.664  ...            1.000000                   1.0
# 5657  64.228 -152.213  ...            0.875000                   1.0
# 5658  38.643  -80.612  ...            1.000000                   1.0
# 5659  44.879  -85.735  ...            1.000000                   1.0
# 5660  43.000 -107.551  ...            0.877296                   1.0
#
#       religious_closure_popwt  paid_sick_leave_popwt  business_closure_popwt  \
# 0                         0.0                   0.00                0.000000
# 1                         0.0                   0.00                0.000000
# 2                         0.0                   0.00                0.000000
# 3                         0.0                   0.00                0.000000
# 4                         0.0                   0.00                0.000000
# ...                       ...                    ...                     ...
# 5656                      0.0                   0.33                1.000000
# 5657                      0.0                   0.33                1.000000
# 5658                      0.0                   0.33                1.000000
# 5659                      0.0                   1.00                1.000000
# 5660                      0.0                   0.33                0.666244
#
#       federal_guidelines_popwt  home_isolation_popwt  \
# 0                          0.0              0.000000
# 1                          0.0              0.000000
# 2                          0.0              0.000000
# 3                          0.0              0.000000
# 4                          0.0              0.000000
# ...                        ...                   ...
# 5656                       1.0              1.000000
# 5657                       1.0              0.000000
# 5658                       1.0              1.000000
# 5659                       1.0              1.000000
# 5660                       1.0              0.509182
#
#       transit_suspension_popwt  policies_enacted  testing_regime
# 0                          0.0             0.000             0.0
# 1                          0.0             0.000             0.0
# 2                          0.0             0.000             0.0
# 3                          0.0             0.000             0.0
# 4                          0.0             0.000             0.0
# ...                        ...               ...             ...
# 5656                       0.0             8.340             0.0
# 5657                       0.0             8.565             0.0
# 5658                       0.0             9.230             0.0
# 5659                       0.0            11.220             0.0
# 5660                       0.0            10.410             0.0
#
# [5661 rows x 38 columns]

# %%
df1 = df1[df1["adm1_name"]==state][['date', 'adm1_name', 'cum_confirmed_cases', 'population', 'pos_cases_quarantine', 'travel_ban_intl_out', 'travel_ban_intl_in', 'travel_ban_local', 'social_distance', 'work_from_home', 'no_gathering', 'school_closure', 'religious_closure', 'home_isolation', 'transit_suspension', 'pos_cases_quarantine_popwt', 'travel_ban_local_popwt', 'social_distance_popwt', 'work_from_home_popwt', 'no_gathering_popwt', 'school_closure_popwt', 'religious_closure_popwt', 'business_closure_popwt', 'federal_guidelines_popwt', 'home_isolation_popwt', 'transit_suspension_popwt']]

# %%
df1
# Out:
#             date adm1_name  cum_confirmed_cases  population  \
# 38    2020-01-22      Iowa                  0.0   3179849.0
# 80    2020-01-23      Iowa                  0.0   3179849.0
# 133   2020-01-24      Iowa                  0.0   3179849.0
# 195   2020-01-25      Iowa                  0.0   3179849.0
# 238   2020-01-26      Iowa                  0.0   3179849.0
# ...          ...       ...                  ...         ...
# 5428  2020-05-07      Iowa              11052.0   3179849.0
# 5473  2020-05-08      Iowa              11447.0   3179849.0
# 5510  2020-05-09      Iowa              11666.0   3179849.0
# 5569  2020-05-10      Iowa              11961.0   3179849.0
# 5614  2020-05-11      Iowa              12368.0   3179849.0
#
#       pos_cases_quarantine  travel_ban_intl_out  travel_ban_intl_in  \
# 38                     0.0                  0.0                   0
# 80                     0.0                  0.0                   0
# 133                    0.0                  0.0                   0
# 195                    0.0                  0.0                   0
# 238                    0.0                  0.0                   0
# ...                    ...                  ...                 ...
# 5428                   0.0                  0.8                   1
# 5473                   0.0                  0.8                   1
# 5510                   0.0                  0.8                   1
# 5569                   0.0                  0.8                   1
# 5614                   0.0                  0.8                   1
#
#       travel_ban_local  social_distance  work_from_home  ...  \
# 38                 0.0             0.00             0.0  ...
# 80                 0.0             0.00             0.0  ...
# 133                0.0             0.00             0.0  ...
# 195                0.0             0.00             0.0  ...
# 238                0.0             0.00             0.0  ...
# ...                ...              ...             ...  ...
# 5428               0.0             0.35             0.0  ...
# 5473               0.0             0.35             0.0  ...
# 5510               0.0             0.35             0.0  ...
# 5569               0.0             0.35             0.0  ...
# 5614               0.0             0.35             0.0  ...
#
#       travel_ban_local_popwt  social_distance_popwt  work_from_home_popwt  \
# 38                       0.0                   0.00                   0.0
# 80                       0.0                   0.00                   0.0
# 133                      0.0                   0.00                   0.0
# 195                      0.0                   0.00                   0.0
# 238                      0.0                   0.00                   0.0
# ...                      ...                    ...                   ...
# 5428                     0.0                   0.35                   0.0
# 5473                     0.0                   0.35                   0.0
# 5510                     0.0                   0.35                   0.0
# 5569                     0.0                   0.35                   0.0
# 5614                     0.0                   0.35                   0.0
#
#       no_gathering_popwt  school_closure_popwt  religious_closure_popwt  \
# 38                 0.000                   0.0                      0.0
# 80                 0.000                   0.0                      0.0
# 133                0.000                   0.0                      0.0
# 195                0.000                   0.0                      0.0
# 238                0.000                   0.0                      0.0
# ...                  ...                   ...                      ...
# 5428               0.875                   1.0                      0.0
# 5473               0.875                   1.0                      0.0
# 5510               0.875                   1.0                      0.0
# 5569               0.875                   1.0                      0.0
# 5614               0.875                   1.0                      0.0
#
#       business_closure_popwt  federal_guidelines_popwt  home_isolation_popwt  \
# 38                      0.00                       0.0              0.000000
# 80                      0.00                       0.0              0.000000
# 133                     0.00                       0.0              0.000000
# 195                     0.00                       0.0              0.000000
# 238                     0.00                       0.0              0.000000
# ...                      ...                       ...                   ...
# 5428                    0.66                       1.0              0.033772
# 5473                    0.66                       1.0              0.033772
# 5510                    0.66                       1.0              0.033772
# 5569                    0.66                       1.0              0.033772
# 5614                    0.66                       1.0              0.033772
#
#       transit_suspension_popwt
# 38                         0.0
# 80                         0.0
# 133                        0.0
# 195                        0.0
# 238                        0.0
# ...                        ...
# 5428                       0.0
# 5473                       0.0
# 5510                       0.0
# 5569                       0.0
# 5614                       0.0
#
# [111 rows x 26 columns]

# %%
df2 = pd.read_csv(r"datasets\2020_US_Region_Mobility_Report.csv")
df2 = df2[(df2["sub_region_1"]==state) & (df2["iso_3166_2_code"]=="US-{}".format(st))]
# [
#     "retail_and_recreation_percent_change_from_baseline,grocery_and_pharmacy_percent_change_from_baseline,parks_percent_change_from_baseline,transit_stations_percent_change_from_baseline,workplaces_percent_change_from_baseline,residential_percent_change_from_baseline".split(",")
# ]
df2
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 181951                  US  United States         Iowa          NaN
# 181952                  US  United States         Iowa          NaN
# 181953                  US  United States         Iowa          NaN
# 181954                  US  United States         Iowa          NaN
# 181955                  US  United States         Iowa          NaN
# ...                    ...            ...          ...          ...
# 182219                  US  United States         Iowa          NaN
# 182220                  US  United States         Iowa          NaN
# 182221                  US  United States         Iowa          NaN
# 182222                  US  United States         Iowa          NaN
# 182223                  US  United States         Iowa          NaN
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 181951         NaN           US-IA               NaN  2020-02-15
# 181952         NaN           US-IA               NaN  2020-02-16
# 181953         NaN           US-IA               NaN  2020-02-17
# 181954         NaN           US-IA               NaN  2020-02-18
# 181955         NaN           US-IA               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 182219         NaN           US-IA               NaN  2020-11-09
# 182220         NaN           US-IA               NaN  2020-11-10
# 182221         NaN           US-IA               NaN  2020-11-11
# 182222         NaN           US-IA               NaN  2020-11-12
# 182223         NaN           US-IA               NaN  2020-11-13
#
#         retail_and_recreation_percent_change_from_baseline  \
# 181951                                                8.0
# 181952                                               10.0
# 181953                                               -2.0
# 181954                                               -3.0
# 181955                                               -3.0
# ...                                                   ...
# 182219                                               -9.0
# 182220                                              -18.0
# 182221                                               -7.0
# 182222                                              -14.0
# 182223                                               -8.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 181951                                               13.0
# 181952                                               18.0
# 181953                                                5.0
# 181954                                                6.0
# 181955                                                6.0
# ...                                                   ...
# 182219                                                8.0
# 182220                                                0.0
# 182221                                               10.0
# 182222                                               -1.0
# 182223                                               11.0
#
#         parks_percent_change_from_baseline  \
# 181951                                24.0
# 181952                                16.0
# 181953                                -8.0
# 181954                                 5.0
# 181955                                -2.0
# ...                                    ...
# 182219                                40.0
# 182220                                -9.0
# 182221                                28.0
# 182222                                24.0
# 182223                                24.0
#
#         transit_stations_percent_change_from_baseline  \
# 181951                                            0.0
# 181952                                           -4.0
# 181953                                           -7.0
# 181954                                           -1.0
# 181955                                            0.0
# ...                                               ...
# 182219                                          -18.0
# 182220                                          -24.0
# 182221                                          -12.0
# 182222                                          -18.0
# 182223                                          -14.0
#
#         workplaces_percent_change_from_baseline  \
# 181951                                      3.0
# 181952                                      2.0
# 181953                                     -8.0
# 181954                                      1.0
# 181955                                      3.0
# ...                                         ...
# 182219                                    -23.0
# 182220                                    -27.0
# 182221                                    -28.0
# 182222                                    -25.0
# 182223                                    -22.0
#
#         residential_percent_change_from_baseline
# 181951                                      -1.0
# 181952                                      -1.0
# 181953                                       4.0
# 181954                                       0.0
# 181955                                       0.0
# ...                                          ...
# 182219                                       8.0
# 182220                                      12.0
# 182221                                      10.0
# 182222                                      10.0
# 182223                                       8.0
#
# [273 rows x 14 columns]

# %%
# TEMP - Do delete
dft = pd.read_csv(r"datasets\2020_US_Region_Mobility_Report.csv")
dft = dft[(dft["sub_region_1"]==state)]
dft
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 181951                  US  United States         Iowa            NaN
# 181952                  US  United States         Iowa            NaN
# 181953                  US  United States         Iowa            NaN
# 181954                  US  United States         Iowa            NaN
# 181955                  US  United States         Iowa            NaN
# ...                    ...            ...          ...            ...
# 203799                  US  United States         Iowa  Wright County
# 203800                  US  United States         Iowa  Wright County
# 203801                  US  United States         Iowa  Wright County
# 203802                  US  United States         Iowa  Wright County
# 203803                  US  United States         Iowa  Wright County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 181951         NaN           US-IA               NaN  2020-02-15
# 181952         NaN           US-IA               NaN  2020-02-16
# 181953         NaN           US-IA               NaN  2020-02-17
# 181954         NaN           US-IA               NaN  2020-02-18
# 181955         NaN           US-IA               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 203799         NaN             NaN           19197.0  2020-11-09
# 203800         NaN             NaN           19197.0  2020-11-10
# 203801         NaN             NaN           19197.0  2020-11-11
# 203802         NaN             NaN           19197.0  2020-11-12
# 203803         NaN             NaN           19197.0  2020-11-13
#
#         retail_and_recreation_percent_change_from_baseline  \
# 181951                                                8.0
# 181952                                               10.0
# 181953                                               -2.0
# 181954                                               -3.0
# 181955                                               -3.0
# ...                                                   ...
# 203799                                                NaN
# 203800                                                NaN
# 203801                                                NaN
# 203802                                                NaN
# 203803                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 181951                                               13.0
# 181952                                               18.0
# 181953                                                5.0
# 181954                                                6.0
# 181955                                                6.0
# ...                                                   ...
# 203799                                                NaN
# 203800                                                NaN
# 203801                                                NaN
# 203802                                                NaN
# 203803                                                NaN
#
#         parks_percent_change_from_baseline  \
# 181951                                24.0
# 181952                                16.0
# 181953                                -8.0
# 181954                                 5.0
# 181955                                -2.0
# ...                                    ...
# 203799                                 NaN
# 203800                                 NaN
# 203801                                 NaN
# 203802                                 NaN
# 203803                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 181951                                            0.0
# 181952                                           -4.0
# 181953                                           -7.0
# 181954                                           -1.0
# 181955                                            0.0
# ...                                               ...
# 203799                                            NaN
# 203800                                            NaN
# 203801                                            NaN
# 203802                                            NaN
# 203803                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 181951                                      3.0
# 181952                                      2.0
# 181953                                     -8.0
# 181954                                      1.0
# 181955                                      3.0
# ...                                         ...
# 203799                                     -8.0
# 203800                                    -15.0
# 203801                                    -13.0
# 203802                                    -16.0
# 203803                                    -12.0
#
#         residential_percent_change_from_baseline
# 181951                                      -1.0
# 181952                                      -1.0
# 181953                                       4.0
# 181954                                       0.0
# 181955                                       0.0
# ...                                          ...
# 203799                                       NaN
# 203800                                       NaN
# 203801                                       NaN
# 203802                                       NaN
# 203803                                       NaN
#
# [21853 rows x 14 columns]

# %%
df3 = pd.merge(df1, df2, on="date")
df3
# Out:
#           date adm1_name  cum_confirmed_cases  population  \
# 0   2020-02-15      Iowa                  0.0   3179849.0
# 1   2020-02-16      Iowa                  0.0   3179849.0
# 2   2020-02-17      Iowa                  0.0   3179849.0
# 3   2020-02-18      Iowa                  0.0   3179849.0
# 4   2020-02-19      Iowa                  0.0   3179849.0
# ..         ...       ...                  ...         ...
# 82  2020-05-07      Iowa              11052.0   3179849.0
# 83  2020-05-08      Iowa              11447.0   3179849.0
# 84  2020-05-09      Iowa              11666.0   3179849.0
# 85  2020-05-10      Iowa              11961.0   3179849.0
# 86  2020-05-11      Iowa              12368.0   3179849.0
#
#     pos_cases_quarantine  travel_ban_intl_out  travel_ban_intl_in  \
# 0                    0.0                  0.2                   1
# 1                    0.0                  0.2                   1
# 2                    0.0                  0.2                   1
# 3                    0.0                  0.2                   1
# 4                    0.0                  0.4                   1
# ..                   ...                  ...                 ...
# 82                   0.0                  0.8                   1
# 83                   0.0                  0.8                   1
# 84                   0.0                  0.8                   1
# 85                   0.0                  0.8                   1
# 86                   0.0                  0.8                   1
#
#     travel_ban_local  social_distance  work_from_home  ...  sub_region_2  \
# 0                0.0             0.00             0.0  ...           NaN
# 1                0.0             0.00             0.0  ...           NaN
# 2                0.0             0.00             0.0  ...           NaN
# 3                0.0             0.00             0.0  ...           NaN
# 4                0.0             0.00             0.0  ...           NaN
# ..               ...              ...             ...  ...           ...
# 82               0.0             0.35             0.0  ...           NaN
# 83               0.0             0.35             0.0  ...           NaN
# 84               0.0             0.35             0.0  ...           NaN
# 85               0.0             0.35             0.0  ...           NaN
# 86               0.0             0.35             0.0  ...           NaN
#
#     metro_area  iso_3166_2_code  census_fips_code  \
# 0          NaN            US-IA               NaN
# 1          NaN            US-IA               NaN
# 2          NaN            US-IA               NaN
# 3          NaN            US-IA               NaN
# 4          NaN            US-IA               NaN
# ..         ...              ...               ...
# 82         NaN            US-IA               NaN
# 83         NaN            US-IA               NaN
# 84         NaN            US-IA               NaN
# 85         NaN            US-IA               NaN
# 86         NaN            US-IA               NaN
#
#     retail_and_recreation_percent_change_from_baseline  \
# 0                                                 8.0
# 1                                                10.0
# 2                                                -2.0
# 3                                                -3.0
# 4                                                -3.0
# ..                                                ...
# 82                                              -26.0
# 83                                              -21.0
# 84                                              -25.0
# 85                                              -21.0
# 86                                              -24.0
#
#     grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                13.0
# 1                                                18.0
# 2                                                 5.0
# 3                                                 6.0
# 4                                                 6.0
# ..                                                ...
# 82                                                8.0
# 83                                               17.0
# 84                                               27.0
# 85                                               25.0
# 86                                                8.0
#
#     parks_percent_change_from_baseline  \
# 0                                 24.0
# 1                                 16.0
# 2                                 -8.0
# 3                                  5.0
# 4                                 -2.0
# ..                                 ...
# 82                               103.0
# 83                               104.0
# 84                               133.0
# 85                                42.0
# 86                                94.0
#
#     transit_stations_percent_change_from_baseline  \
# 0                                             0.0
# 1                                            -4.0
# 2                                            -7.0
# 3                                            -1.0
# 4                                             0.0
# ..                                            ...
# 82                                          -14.0
# 83                                           -9.0
# 84                                           -8.0
# 85                                          -17.0
# 86                                          -13.0
#
#     workplaces_percent_change_from_baseline  \
# 0                                       3.0
# 1                                       2.0
# 2                                      -8.0
# 3                                       1.0
# 4                                       3.0
# ..                                      ...
# 82                                    -38.0
# 83                                    -36.0
# 84                                    -18.0
# 85                                    -22.0
# 86                                    -35.0
#
#     residential_percent_change_from_baseline
# 0                                       -1.0
# 1                                       -1.0
# 2                                        4.0
# 3                                        0.0
# 4                                        0.0
# ..                                       ...
# 82                                      15.0
# 83                                      13.0
# 84                                       7.0
# 85                                       5.0
# 86                                      13.0
#
# [87 rows x 39 columns]

# %%
import c3aidatalake

# %%
# Fetch participants who are located in California and who have a relatively strong intent to wear a mask in public because of COVID-19
survey = c3aidatalake.fetch(
    "surveydata",
    {
        "spec": {
            "filter": "location == '{}_UnitedStates'".format(state.replace(" ", ""))
        }
    },
    get_all = True
)

survey.columns
# Out:
# Index(['id', 'annualHouseholdIncome', 'birthYear2020', 'coronavirusConcern',
#        'coronavirusEmployment', 'coronavirusIntent_Mask',
#        'coronavirusIntent_SixFeet', 'coronavirusIntent_StayHome',
#        'coronavirusIntent_WashHands', 'coronavirusLocalCommunity',
#        'coronavirusSupportSystem', 'coronavirusSymptoms',
#        'ratioOfAdultHospitalization', 'coronavirusWhenShouldReopen',
#        'education', 'ethnicity', 'gender', 'hasCoronavirusBelief',
#        'politicalBelief', 'politicalParty', 'religion', 'religiosity',
#        'trumpApproval', 'zipcodePrefix', 'startTime', 'coronaSimilarFlu',
#        'coronaOnlyElderly', 'youngInvulnerable', 'elderlyMoreRisk',
#        'coronaAllHospitalize', 'coronaKillsMost', 'ethnicitySpreadsCovid',
#        'allSpreadCovid', 'nonNativesSpreadCovid', 'asymptomaticSpread',
#        'onlySickSpread', 'infectFromAnimal', 'location.id'],
#       dtype='object')

# %%
survey.dropna(inplace=True)
survey = survey[["coronavirusIntent_Mask", "coronavirusIntent_SixFeet","startTime"]].mean()
survey
# Out:
# coronavirusIntent_Mask       65.869863
# coronavirusIntent_SixFeet    74.541096
# dtype: float64

# %%
df4 = pd.concat([df3, 
                 pd.Series(survey["coronavirusIntent_Mask"], 
                           index=df3.index, name='mask_intent'),
                 pd.Series(survey["coronavirusIntent_SixFeet"], 
                           index=df3.index, name='social_distance_intent')], axis=1)
df4
# Out:
#           date adm1_name  cum_confirmed_cases  population  \
# 0   2020-02-15      Iowa                  0.0   3179849.0
# 1   2020-02-16      Iowa                  0.0   3179849.0
# 2   2020-02-17      Iowa                  0.0   3179849.0
# 3   2020-02-18      Iowa                  0.0   3179849.0
# 4   2020-02-19      Iowa                  0.0   3179849.0
# ..         ...       ...                  ...         ...
# 82  2020-05-07      Iowa              11052.0   3179849.0
# 83  2020-05-08      Iowa              11447.0   3179849.0
# 84  2020-05-09      Iowa              11666.0   3179849.0
# 85  2020-05-10      Iowa              11961.0   3179849.0
# 86  2020-05-11      Iowa              12368.0   3179849.0
#
#     pos_cases_quarantine  travel_ban_intl_out  travel_ban_intl_in  \
# 0                    0.0                  0.2                   1
# 1                    0.0                  0.2                   1
# 2                    0.0                  0.2                   1
# 3                    0.0                  0.2                   1
# 4                    0.0                  0.4                   1
# ..                   ...                  ...                 ...
# 82                   0.0                  0.8                   1
# 83                   0.0                  0.8                   1
# 84                   0.0                  0.8                   1
# 85                   0.0                  0.8                   1
# 86                   0.0                  0.8                   1
#
#     travel_ban_local  social_distance  work_from_home  ...  iso_3166_2_code  \
# 0                0.0             0.00             0.0  ...            US-IA
# 1                0.0             0.00             0.0  ...            US-IA
# 2                0.0             0.00             0.0  ...            US-IA
# 3                0.0             0.00             0.0  ...            US-IA
# 4                0.0             0.00             0.0  ...            US-IA
# ..               ...              ...             ...  ...              ...
# 82               0.0             0.35             0.0  ...            US-IA
# 83               0.0             0.35             0.0  ...            US-IA
# 84               0.0             0.35             0.0  ...            US-IA
# 85               0.0             0.35             0.0  ...            US-IA
# 86               0.0             0.35             0.0  ...            US-IA
#
#     census_fips_code  retail_and_recreation_percent_change_from_baseline  \
# 0                NaN                                                8.0
# 1                NaN                                               10.0
# 2                NaN                                               -2.0
# 3                NaN                                               -3.0
# 4                NaN                                               -3.0
# ..               ...                                                ...
# 82               NaN                                              -26.0
# 83               NaN                                              -21.0
# 84               NaN                                              -25.0
# 85               NaN                                              -21.0
# 86               NaN                                              -24.0
#
#     grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                13.0
# 1                                                18.0
# 2                                                 5.0
# 3                                                 6.0
# 4                                                 6.0
# ..                                                ...
# 82                                                8.0
# 83                                               17.0
# 84                                               27.0
# 85                                               25.0
# 86                                                8.0
#
#     parks_percent_change_from_baseline  \
# 0                                 24.0
# 1                                 16.0
# 2                                 -8.0
# 3                                  5.0
# 4                                 -2.0
# ..                                 ...
# 82                               103.0
# 83                               104.0
# 84                               133.0
# 85                                42.0
# 86                                94.0
#
#     transit_stations_percent_change_from_baseline  \
# 0                                             0.0
# 1                                            -4.0
# 2                                            -7.0
# 3                                            -1.0
# 4                                             0.0
# ..                                            ...
# 82                                          -14.0
# 83                                           -9.0
# 84                                           -8.0
# 85                                          -17.0
# 86                                          -13.0
#
#     workplaces_percent_change_from_baseline  \
# 0                                       3.0
# 1                                       2.0
# 2                                      -8.0
# 3                                       1.0
# 4                                       3.0
# ..                                      ...
# 82                                    -38.0
# 83                                    -36.0
# 84                                    -18.0
# 85                                    -22.0
# 86                                    -35.0
#
#     residential_percent_change_from_baseline  mask_intent  \
# 0                                       -1.0    65.869863
# 1                                       -1.0    65.869863
# 2                                        4.0    65.869863
# 3                                        0.0    65.869863
# 4                                        0.0    65.869863
# ..                                       ...          ...
# 82                                      15.0    65.869863
# 83                                      13.0    65.869863
# 84                                       7.0    65.869863
# 85                                       5.0    65.869863
# 86                                      13.0    65.869863
#
#     social_distance_intent
# 0                74.541096
# 1                74.541096
# 2                74.541096
# 3                74.541096
# 4                74.541096
# ..                     ...
# 82               74.541096
# 83               74.541096
# 84               74.541096
# 85               74.541096
# 86               74.541096
#
# [87 rows x 41 columns]

# %%
mask_mandate = pd.read_csv("datasets\mask_mandates.txt", sep=",")
# print(mask_mandate.columns)
mask_mandate["state_wide_effect"] = pd.to_datetime(mask_mandate["state_wide_effect"].astype(str), format='%m/%d/%Y')
# pd.to_datetime(mask_mandate["state_wide_effect"]).dt.strftime('%m/%d/%Y')
m_date = mask_mandate[mask_mandate["State"]==state]["state_wide_effect"]
m_date = m_date.values[0]
# mask_mandate

# %%
df5 = pd.concat([df4, 
                 pd.Series(0, index=df4.index, name='mask_mandate')], axis=1)
df5['date'] = pd.to_datetime(df5["date"].astype(str))
# print(df5.dtypes)
df5.loc[df5['date']>=m_date, 'mask_mandate'] = 1
df5[['date', 'mask_mandate']]
# Out:
#          date  mask_mandate
# 0  2020-02-15             0
# 1  2020-02-16             0
# 2  2020-02-17             0
# 3  2020-02-18             0
# 4  2020-02-19             0
# ..        ...           ...
# 82 2020-05-07             0
# 83 2020-05-08             0
# 84 2020-05-09             0
# 85 2020-05-10             0
# 86 2020-05-11             0
#
# [87 rows x 2 columns]

# %%
print(df5.columns)
# Out:
# Index(['date', 'adm1_name', 'cum_confirmed_cases', 'population',
#        'pos_cases_quarantine', 'travel_ban_intl_out', 'travel_ban_intl_in',
#        'travel_ban_local', 'social_distance', 'work_from_home', 'no_gathering',
#        'school_closure', 'religious_closure', 'home_isolation',
#        'transit_suspension', 'pos_cases_quarantine_popwt',
#        'travel_ban_local_popwt', 'social_distance_popwt',
#        'work_from_home_popwt', 'no_gathering_popwt', 'school_closure_popwt',
#        'religious_closure_popwt', 'business_closure_popwt',
#        'federal_guidelines_popwt', 'home_isolation_popwt',
#        'transit_suspension_popwt', 'country_region_code', 'country_region',
#        'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code',
#        'census_fips_code',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline', 'mask_intent',
#        'social_distance_intent', 'mask_mandate'],
#       dtype='object')

# %%
df5.to_csv(r"datasets\StatesData\new_{}.csv".format(state), index=False)
